# %% [markdown]
# ## Lab 1 : Text Preprocessing
#
# Student Name  : Chong Wei Yi
#
# Student Number: A180497

# %% [markdown]
# In this activity we will observe six text preprocessing techniqes as follows:
#
# 1) convert text to lowercase
#
# 2) remove numbers
#
# 3) remove punctuation
#
# 4) remove whitespace
#
# 5) remove stopword
#
# 6) tokenization
#
# Observe the given examples for text preprocessing for each of the process.

# %% [markdown]
# **Convert text to lowercase.**
#
# Example 1. Convert text to lowercase

# %%
input_str = "The 5 biggest countries by population in 2017 are China, India, United States, Indonesia, and Brazil."
input_str = input_str.lower()
print(input_str)
# Out:
# the 5 biggest countries by population in 2017 are china, india, united states, indonesia, and brazil.

# %% [markdown]
# **Remove numbers**

# %%
import re   #regular expression operations
input_str = "Box A contains 3 red and 5 white balls, while Box B contains 4 red and 2 blue balls."
input_str = re.sub(r'\d+', '', input_str) #replace digits with ''
print(input_str)
# Out:
# Box A contains  red and  white balls, while Box B contains  red and  blue balls.

# %% [markdown]
# **Remove punctuation**
#
# The following code removes this set of symbols [!”#$%&’()*+,-./:;<=>?@[\]^_`{|}~]:

# %%
import string
input_str = "This &is [an] example? {of} string. with.? punctuation!!!!" # Sample string

input_str = input_str.translate(str.maketrans('', '', string.punctuation))
print(input_str)
# Out:
# This is an example of string with punctuation

# %% [markdown]
# **Remove whitespaces**
#
# To remove leading and ending spaces, you can use the strip() function:

# %%
input_str = " \t a string example\t "
input_str = input_str.strip()
input_str
# Out:
# 'a string example'

# %% [markdown]
# **Remove stop words and tokenization**
#
# “Stop words” are the most common words in a language like “the”, “a”, “on”, “is”, “all”. These words do not carry important meaning and are usually removed from texts. It is possible to remove stop words using Natural Language Toolkit (NLTK), a suite of libraries and programs for symbolic and statistical natural language processing.

# %%
import nltk   #natural language toolkit
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = "Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus."
print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("\nWord tokenization output:")
print(tokens)
result = [i for i in tokens if not i in stop_words]
for word in result:
  print(word)
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
#
# Word tokenization output:
# ['Coronavirus', 'disease', '(', 'COVID-19', ')', 'is', 'an', 'infectious', 'disease', 'caused', 'by', 'the', 'SARS-CoV-2', 'virus', '.']
# Coronavirus
# disease
# (
# COVID-19
# )
# infectious
# disease
# caused
# SARS-CoV-2
# virus
# .
# ['Coronavirus', 'disease', '(', 'COVID-19', ')', 'infectious', 'disease', 'caused', 'SARS-CoV-2', 'virus', '.']

# %% [markdown]
# ##Lab Activity

# %% [markdown]
# ####1) Read text from a file

# %%
input_file = "Lab1 TP2043.txt"
file = open(input_file, "r")

# %%
# Print the path of file

file.name
# Out:
# 'Lab1 TP2043.txt'

# %%
# Print the mode of file, either 'r' or 'w'

file.mode
# Out:
# 'r'

# %%
# Read the file

FileContent = file.read()
FileContent
# Out:
# 'What is heart disease?\nThe term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.\nWhat are the symptoms of heart disease?\nSometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1\nHeart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.\nArrhythmia: Fluttering feelings in the chest (palpitations).\nHeart failure: Shortness of breath, fatigue, or swelling of the feet, ankles, legs, abdomen, or neck veins.\nWhat are the risk factors for heart disease?\nHigh blood pressure, high blood cholesterol, and smoking are key risk f
# ...

# %% [markdown]
# ####2a) Observe tokenization output before adding stopword removal.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = FileContent
print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("\nWord tokenization output:")
print(tokens)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : What is heart disease?
# The term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.
# What are the symptoms of heart disease?
# Sometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1
# Heart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.
# ...

# %% [markdown]
# ####2b) Observe token frequency before adding stopword removal.

# %%
from collections import Counter
print("Token frequency:")
Counter(tokens)
# Out:
# Token frequency:
# Counter({'%': 1,
#          "''": 2,
#          '(': 3,
#          ')': 3,
#          ',': 21,
#          '.': 8,
#          '47': 1,
#          ':': 3,
#          '?': 3,
#          'About': 1,
#          'Arrhythmia': 1,
#          'CAD': 1,
#          'Chest': 1,
#          'Decreased': 1,
#          'Diabetes': 1,
#          'Excessive': 1,
#          'Fluttering': 1,
#          'Heart': 2,
#          'High': 1,
#          'Overweight': 1,
#          'Physical': 1,
#          'Several': 1,
#          'Shortness': 1,
#          'Sometimes': 1,
#          'States': 2,
#          'The': 2,
#          'Unhealthy': 1,
#          'United': 2,
#          'What': 3,
#          'When': 1,
#          '``': 2,
#          'a': 4,
#          'abdomen': 1,
#          'affects': 1,
#          'alcohol': 1,
#          'also': 1,
#          'an': 1,
#          'and': 5,
#          'ankles': 1,
#          'are': 3,
#          'arrhythmia': 1,
#          'artery': 1,
# ...

# %% [markdown]
# ####2c) Observe 20 most common words in the text

# %%
print("20 most common words in the text:")
Counter(tokens).most_common(20)
# Out:
# 20 most common words in the text:
# [(',', 21),
#  ('heart', 13),
#  ('disease', 9),
#  ('of', 9),
#  ('.', 8),
#  ('the', 8),
#  ('or', 7),
#  ('and', 5),
#  ('blood', 4),
#  ('a', 4),
#  ('risk', 4),
#  ('What', 3),
#  ('?', 3),
#  ('in', 3),
#  ('(', 3),
#  (')', 3),
#  ('attack', 3),
#  ('are', 3),
#  ('symptoms', 3),
#  (':', 3)]

# %% [markdown]
# ####3a) Improve code in (2a) by adding back the stopword removal.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = FileContent
print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)

print("Word Tokenization output:") 
print(tokens)
result = [i for i in tokens if not i in stop_words]
print("\nAfter stopword removal:")  
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : What is heart disease?
# The term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.
# What are the symptoms of heart disease?
# Sometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1
# Heart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.
# ...

# %% [markdown]
# ####3b) Observe 20 most common words in the text after you remove the stopwords.
#
# Hint: use code (2c)

# %%
# write your code here
print("20 most common words in the text:")
Counter(result).most_common(20)
# Out:
# 20 most common words in the text:
# [(',', 21),
#  ('heart', 13),
#  ('disease', 9),
#  ('.', 8),
#  ('blood', 4),
#  ('risk', 4),
#  ('What', 3),
#  ('?', 3),
#  ('(', 3),
#  (')', 3),
#  ('attack', 3),
#  ('symptoms', 3),
#  (':', 3),
#  ('The', 2),
#  ('``', 2),
#  ("''", 2),
#  ('conditions', 2),
#  ('United', 2),
#  ('States', 2),
#  ('flow', 2)]

# %% [markdown]
# ####4a) Improve code in (3a) by adding punctuation removal

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = FileContent

print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))
input_str = input_str.translate(str.maketrans('', '', string.punctuation)).replace('“','').replace('”','')

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("Word Tokenization output:") 
print(tokens)
result = [i for i in tokens if not i in stop_words]
print("\nAfter stopword, punctuation removal:")  
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : What is heart disease?
# The term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.
# What are the symptoms of heart disease?
# Sometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1
# Heart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.
# ...

# %% [markdown]
# ####4b) Observe 20 most common words in the text after you remove the punctuation.
#
# Hint: use code (2c)

# %%
# write your code here
print("20 most common words in the text:")
Counter(result).most_common(20)
# Out:
# 20 most common words in the text:
# [('heart', 13),
#  ('disease', 9),
#  ('blood', 4),
#  ('risk', 4),
#  ('What', 3),
#  ('attack', 3),
#  ('symptoms', 3),
#  ('The', 2),
#  ('conditions', 2),
#  ('United', 2),
#  ('States', 2),
#  ('flow', 2),
#  ('may', 2),
#  ('failure', 2),
#  ('Heart', 2),
#  ('pain', 2),
#  ('discomfort', 2),
#  ('upper', 2),
#  ('neck', 2),
#  ('fatigue', 2)]

# %% [markdown]
# ####5a) Improve code in (4a) by adding lowercase

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = FileContent

print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))
input_str = input_str.translate(str.maketrans('', '', string.punctuation)).replace('“','').replace('”','')
input_str = input_str.lower()

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("Word Tokenization output:") 
print(tokens)
result = [i for i in tokens if not i in stop_words]
print("\nAfter stopword, punctuation removal, adding lowercase:")  
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : What is heart disease?
# The term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.
# What are the symptoms of heart disease?
# Sometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1
# Heart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.
# ...

# %% [markdown]
# ####5b) Observe 20 most common words in the text after you set all word to lower case
#
# Hint: use code (2c)

# %%
# write your code here
print("20 most common words in the text:")
Counter(result).most_common(20)
# Out:
# 20 most common words in the text:
# [('heart', 15),
#  ('disease', 9),
#  ('blood', 4),
#  ('risk', 4),
#  ('attack', 3),
#  ('symptoms', 3),
#  ('several', 2),
#  ('conditions', 2),
#  ('united', 2),
#  ('states', 2),
#  ('flow', 2),
#  ('may', 2),
#  ('failure', 2),
#  ('arrhythmia', 2),
#  ('chest', 2),
#  ('pain', 2),
#  ('discomfort', 2),
#  ('upper', 2),
#  ('neck', 2),
#  ('fatigue', 2)]

# %% [markdown]
# ####6a) Improve code in (5a) by removing number and whitespace

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
input_str = FileContent

print("\nInput sentence :",input_str)

stop_words = set(stopwords.words('english'))
input_str = input_str.translate(str.maketrans('', '', string.punctuation)).replace('“','').replace('”','')
input_str = input_str.lower()
input_str = re.sub(r'\d+','',input_str)
# remove whitespace
input_str = input_str.strip()             # for leading and ending whitespace only
input_str = " ".join(input_str.split())   #remove duplicated spaces
#input_str = input_str.replace(" ", "")   # remove all space characters

from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("Word Tokenization output:") 
print(tokens)
result = [i for i in tokens if not i in stop_words]
print("\nAfter stopword, punctuation removal, adding lowercase, removing number and whitespace:")  
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# Input sentence : What is heart disease?
# The term "heart disease" refers to several types of heart conditions. The most common type of heart disease in the United States is coronary artery disease (CAD), which affects the blood flow to the heart. Decreased blood flow can cause a heart attack.
# What are the symptoms of heart disease?
# Sometimes heart disease may be "silent" and not diagnosed until a person experiences signs or symptoms of a heart attack, heart failure, or an arrhythmia. When these events happen, symptoms may include1
# Heart attack: Chest pain or discomfort, upper back or neck pain, indigestion, heartburn, nausea or vomiting, extreme fatigue, upper body discomfort, dizziness, and shortness of breath.
# ...

# %% [markdown]
# ####6b) Observe 20 most common words in the text after you remove number and white space.
#
# Hint: use code (2c)

# %%
# write your code here
print("20 most common words in the text:")
Counter(result).most_common(20)
# Out:
# 20 most common words in the text:
# [('heart', 15),
#  ('disease', 9),
#  ('blood', 4),
#  ('risk', 4),
#  ('attack', 3),
#  ('symptoms', 3),
#  ('factors', 3),
#  ('several', 2),
#  ('conditions', 2),
#  ('united', 2),
#  ('states', 2),
#  ('flow', 2),
#  ('may', 2),
#  ('failure', 2),
#  ('arrhythmia', 2),
#  ('chest', 2),
#  ('pain', 2),
#  ('discomfort', 2),
#  ('upper', 2),
#  ('neck', 2)]

# %%
# !pip install wordcloud
