# %% [markdown]
# ## **Information Extraction by Using Natural Language Processing**

# %% [markdown]
# We usually wish to extract some meaning from text while working with it. Extracting events or things from text is a common activity. These tasks are called information extraction.
#
# In this activity, we will do information extraction by using Natural Language Processing (NLP). There are many NLP tools available that can be used to extract information such as:
#
# a) Natural Language Toolkit
#
# b) Malaya Toolkit (Malay text)

# %% [markdown]
# ## Part Of Speech Tagging
# Parts of speech provide useful indications for identifying generic objects, activities, relationships, emotions, and more.
#
# *   Noun : objects
# *   Verb : activity/relationship
# *   Adjective : emotion
#
#
# Lets analyse the followig sentence:
#
# "*Monkeypox was first discovered in 1958 when two outbreaks of a pox-like disease occurred in colonies of monkeys kept for research, hence the name ‘monkeypox*.’ "

# %%
sentence = "Monkeypox was first discovered in 1958 when two outbreaks of a pox-like disease occurred in colonies of monkeys kept for research, hence the name ‘monkeypox.’"

# %% [markdown]
# ### a) NLTK

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('words')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize each sentence into words: token_sentences
token_sentence = word_tokenize(sentence) 
print(token_sentence)

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentence = nltk.pos_tag(token_sentence) 
print(pos_sentence)

# Observe output style
for word_post in pos_sentence:
  print (word_post)
# Out:
# ['Monkeypox', 'was', 'first', 'discovered', 'in', '1958', 'when', 'two', 'outbreaks', 'of', 'a', 'pox-like', 'disease', 'occurred', 'in', 'colonies', 'of', 'monkeys', 'kept', 'for', 'research', ',', 'hence', 'the', 'name', '‘', 'monkeypox', '.', '’']
# [('Monkeypox', 'NNP'), ('was', 'VBD'), ('first', 'RB'), ('discovered', 'VBN'), ('in', 'IN'), ('1958', 'CD'), ('when', 'WRB'), ('two', 'CD'), ('outbreaks', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('pox-like', 'JJ'), ('disease', 'NN'), ('occurred', 'VBD'), ('in', 'IN'), ('colonies', 'NNS'), ('of', 'IN'), ('monkeys', 'NNS'), ('kept', 'VBD'), ('for', 'IN'), ('research', 'NN'), (',', ','), ('hence', 'RB'), ('the', 'DT'), ('name', 'NN'), ('‘', 'NNP'), ('monkeypox', 'NN'), ('.', '.'), ('’', 'NN')]
# ('Monkeypox', 'NNP')
# ('was', 'VBD')
# ('first', 'RB')
# ('discovered', 'VBN')
# ('in', 'IN')
# ('1958', 'CD')
# ('when', 'WRB')
# ('two', 'CD')
# ('outbreaks', 'NNS')
# ('of', 'IN')
# ('a', 'DT')
# ('pox-like', 'JJ')
# ('disease', 'NN')
# ...

# %%
# Exract noun from the POST
for word_post in pos_sentence:
  if(word_post[1]=="NN"):
    print(word_post[0])
  if(word_post[1]=="NNP"):
    print(word_post[0])
  if(word_post[1]=="NNS"):
    print(word_post[0])
# Out:
# Monkeypox
# outbreaks
# disease
# colonies
# monkeys
# research
# name
# ‘
# monkeypox
# ’

# %% [markdown]
# ### b) Malaya Toolkit

# %%
# !pip install malaya
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import malaya

# %%
malaya.pos.describe()
# Out:
#       Tag                           Description
# 0   ADJ    Adjective, kata sifat
# 1   ADP    Adposition
# 2   ADV    Adverb, kata keterangan
# 3   ADX    Auxiliary verb, kata kerja tambahan
# 4   CCONJ  Coordinating conjuction, kata hubung
# 5   DET    Determiner, kata penentu
# 6   NOUN    Noun, kata nama
# 7   NUM    Number, nombor
# 8   PART   Particle
# 9   PRON   Pronoun, kata ganti
# 10  PROPN  Proper noun, kata ganti nama khas
# 11  SCONJ  Subordinating conjunction
# 12  SYM    Symbol
# 13  VERB   Verb, kata kerja
# 14  X      Other

# %%
malaya.pos.available_transformer()
# Out:
#              Size (MB)  Quantized Size (MB)  macro precision  macro recall  \
# bert         426.4      111.00               0.93280          0.93129
# tiny-bert    57.7       15.40                0.92810          0.92649
# albert       48.7       12.80                0.93199          0.91948
# tiny-albert  22.4       5.98                 0.90579          0.89501
# xlnet        446.6      118.00               0.93303          0.93222
# alxlnet      46.8       13.30                0.92732          0.93046
#
#              macro f1-score
# bert         0.93181
# tiny-bert    0.92704
# albert       0.92547
# tiny-albert  0.90002
# xlnet        0.93236
# alxlnet      0.92819

# %% [markdown]
# Lets try to tag the following sentence:
#
# *'KUALA LUMPUR: Sempena sambutan Aidilfitri minggu depan, Perdana Menteri Tun Dr Mahathir Mohamad dan Menteri Pengangkutan Anthony Loke Siew Fook menitipkan pesanan khas kepada orang ramai yang mahu pulang ke kampung halaman masing-masing. Dalam video pendek terbitan Jabatan Keselamatan Jalan Raya (JKJR) itu, Dr Mahathir menasihati mereka supaya berhenti berehat dan tidur sebentar  sekiranya mengantuk ketika memandu.'*

# %%
string = 'KUALA LUMPUR: Sempena sambutan Aidilfitri minggu depan, Perdana Menteri Tun Dr Mahathir Mohamad dan Menteri Pengangkutan Anthony Loke Siew Fook menitipkan pesanan khas kepada orang ramai yang mahu pulang ke kampung halaman masing-masing. Dalam video pendek terbitan Jabatan Keselamatan Jalan Raya (JKJR) itu, Dr Mahathir menasihati mereka supaya berhenti berehat dan tidur sebentar sekiranya mengantuk ketika memandu.'

# %%
# Can choose based on the list of available transformer POS models
model = malaya.pos.transformer(model = 'albert')

# %%
quantized_model = malaya.pos.transformer(model = 'albert', quantized = True)
# Out:
# WARNING:huggingface:Load quantized model will cause accuracy drop.

# %%
model.predict(string)
# Out:
# [('KUALA', 'PROPN'),
#  ('LUMPUR', 'PROPN'),
#  (':', 'PUNCT'),
#  ('Sempena', 'ADP'),
#  ('sambutan', 'NOUN'),
#  ('Aidilfitri', 'NOUN'),
#  ('minggu', 'NOUN'),
#  ('depan', 'ADJ'),
#  (',', 'PUNCT'),
#  ('Perdana', 'PROPN'),
#  ('Menteri', 'PROPN'),
#  ('Tun', 'PROPN'),
#  ('Dr', 'PROPN'),
#  ('Mahathir', 'PROPN'),
#  ('Mohamad', 'PROPN'),
#  ('dan', 'CCONJ'),
#  ('Menteri', 'PROPN'),
#  ('Pengangkutan', 'PROPN'),
#  ('Anthony', 'PROPN'),
#  ('Loke', 'PROPN'),
#  ('Siew', 'PROPN'),
#  ('Fook', 'PROPN'),
#  ('menitipkan', 'VERB'),
#  ('pesanan', 'NOUN'),
#  ('khas', 'ADJ'),
#  ('kepada', 'ADP'),
#  ('orang', 'NOUN'),
#  ('ramai', 'ADJ'),
#  ('yang', 'PRON'),
#  ('mahu', 'ADV'),
#  ('pulang', 'VERB'),
#  ('ke', 'ADP'),
#  ('kampung', 'NOUN'),
#  ('halaman', 'NOUN'),
#  ('masing-masing', 'DET'),
#  ('.', 'PUNCT'),
#  ('Dalam', 'ADP'),
#  ('video', 'NOUN'),
#  ('pendek', 'ADJ'),
#  ('terbitan', 'NOUN'),
#  ('Jabatan', 'PROPN'),
#  ('Keselamatan', 'PROPN'),
#  ('Jalan', 'PROPN'),
# ...

# %% [markdown]
# ## Named Entity Extraction (NER)
#
# The task of finding specified items (nouns) in text is known as named-entity recognition (NER). Who? What? When? Where?

# %% [markdown]
# ### a) NER by using NLTK

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
with open('monkeypox.txt', 'r') as file:
    article = file.read()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize the article into sentences: sentences
sentences = sent_tokenize(article)

# Tokenize each sentence into words: token_sentences
token_sentences = [word_tokenize(sent) for sent in sentences]

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences]

# Create the named entity chunks: chunked_sentences
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary=True)

# Test for stems of the tree with 'NE' tags
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, "label") and chunk.label() == 'NE':
            print(chunk)
# Out:
# (NE Africa/NNP)
# (NE MSM/NNP)
# (NE WHO/NNP)
# (NE United/NNP Kingdom/NNP)
# (NE Spain/NNP)
# (NE Portugal/NNP)
# (NE United/NNP States/NNPS)
# (NE Canada/NNP)
# (NE Sweden/NNP)
# (NE Italy/NNP)
# (NE Belgium/NNP)
# (NE France/NNP)
# (NE Germany/NNP)
# (NE Netherlands/NNP)
# (NE Australia/NNP)
# (NE Israel/NNP)
# (NE David/NNP Heymann/NNP)
# (NE London/NNP School/NNP)
# (NE Hygiene/NNP)
# (NE Tropical/NNP Medicine/NNP)
# (NE Africa/NNP)
# (NE Monkeypox/NNP)
# (NE Rosamund/NNP Lewis/NNP)
# (NE WHO/NNP)
# (NE WHO/NNP)
# (NE Technical/NNP Advisory/NNP Group/NNP)
# (NE Infectious/NNP Hazards/NNP)
# (NE Pandemic/NNP)
# (NE Epidemic/NNP Potential/NNP)
# (NE Heymann/NNP)
# (NE Democratic/JJ Republic/NNP)
# (NE Congo/NNP)
# (NE Outbreaks/NNP)
# (NE Africa/NNP)
# (NE United/NNP States/NNPS)
# (NE Ghana/NNP)
# (NE Congo/NNP Basin/NNP)
# (NE West/NNP African/NNP)
# (NE Outbreaks/NNP)

# %% [markdown]
# In this activity, we will display some extracted named entities from a newspaper article in order to investigate the variety of named entity types found in the articles. We'll use ner categories, a defaultdict with keys representing each named entity group type and values counting the number of each named entity type.

# %%
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary=False)

# %%
import matplotlib.pyplot as plt

# %%
from collections import defaultdict

# Create the defaultdict: ner_categories
ner_categories = defaultdict(int)

# Create the nested for loop
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, 'label'):
            ner_categories[chunk.label()] += 1
            
# Create a list from the dictionary keys for the cart labels: labels
labels = list(ner_categories.keys())

# Create a list of the values: values
values = [ner_categories.get(l) for l in labels]

# Create the pie chart
fig = plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140);

# %% [markdown]
# ### b) Malay Natural Language Toolkit

# %%
# !pip install malaya
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import malaya

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
malaya.entity.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#             Tag  \
# 0  OTHER
# 1  law
# 2  location
# 3  organization
# 4  person
# 5  quantity
# 6  time
# 7  event
#
#                                                              Description
# 0  other
# 1  law, regulation, related law documents, documents, etc
# 2  location, place
# 3  organization, company, government, facilities, etc
# 4  person, group of people, believes, unique arts (eg; food, drink), etc
# 5  numbers, quantity
# 6  date, day, time, etc
# 7  unique event happened, etc

# %%
malaya.entity.describe_ontonotes5()
# Out:
#             Tag                                           Description
# 0   OTHER        other
# 1   ADDRESS      Address of physical location.
# 2   PERSON       People, including fictional.
# 3   NORP         Nationalities or religious or political groups.
# 4   FAC          Buildings, airports, highways, bridges, etc.
# 5   ORG          Companies, agencies, institutions, etc.
# 6   GPE          Countries, cities, states.
# 7   LOC          Non-GPE locations, mountain ranges, bodies of water.
# 8   PRODUCT      Objects, vehicles, foods, etc. (Not services.)
# 9   EVENT        Named hurricanes, battles, wars, sports events, etc.
# 10  WORK_OF_ART  Titles of books, songs, etc.
# 11  LAW          Named documents made into laws.
# 12  LANGUAGE     Any named language.
# 13  DATE         Absolute or relative dates or periods.
# 14  TIME         Times smaller than a day.
# 15  PERCENT      Percentage, including "%".
# 16  MONEY        Monetary values, including unit.
# ...

# %%
string = 'KUALA LUMPUR: Sempena sambutan Aidilfitri minggu depan, Perdana Menteri Tun Dr Mahathir Mohamad dan Menteri Pengangkutan Anthony Loke Siew Fook menitipkan pesanan khas kepada orang ramai yang mahu pulang ke kampung halaman masing-masing. Dalam video pendek terbitan Jabatan Keselamatan Jalan Raya (JKJR) itu, Dr Mahathir menasihati mereka supaya berhenti berehat dan tidur sebentar  sekiranya mengantuk ketika memandu.'
string1 = 'memperkenalkan Husein, dia sangat comel, berumur 25 tahun, bangsa melayu, agama islam, tinggal di cyberjaya malaysia, bercakap bahasa melayu, semua membaca buku undang-undang kewangan, dengar laju Siti Nurhaliza - Seluruh Cinta sambil makan ayam goreng KFC'

# %%
model = malaya.entity.transformer(model = 'alxlnet')

# %%
quantized_model = malaya.entity.transformer(model = 'alxlnet', quantized = True)
# Out:
# WARNING:huggingface:Load quantized model will cause accuracy drop.

# %%
model.predict(string)
# Out:
# [('KUALA', 'location'),
#  ('LUMPUR', 'location'),
#  (':', 'OTHER'),
#  ('Sempena', 'OTHER'),
#  ('sambutan', 'OTHER'),
#  ('Aidilfitri', 'OTHER'),
#  ('minggu', 'time'),
#  ('depan', 'time'),
#  (',', 'OTHER'),
#  ('Perdana', 'person'),
#  ('Menteri', 'person'),
#  ('Tun', 'person'),
#  ('Dr', 'person'),
#  ('Mahathir', 'person'),
#  ('Mohamad', 'person'),
#  ('dan', 'OTHER'),
#  ('Menteri', 'organization'),
#  ('Pengangkutan', 'organization'),
#  ('Anthony', 'person'),
#  ('Loke', 'person'),
#  ('Siew', 'person'),
#  ('Fook', 'person'),
#  ('menitipkan', 'OTHER'),
#  ('pesanan', 'OTHER'),
#  ('khas', 'OTHER'),
#  ('kepada', 'OTHER'),
#  ('orang', 'OTHER'),
#  ('ramai', 'OTHER'),
#  ('yang', 'OTHER'),
#  ('mahu', 'OTHER'),
#  ('pulang', 'OTHER'),
#  ('ke', 'OTHER'),
#  ('kampung', 'OTHER'),
#  ('halaman', 'OTHER'),
#  ('masing-masing', 'OTHER'),
#  ('.', 'OTHER'),
#  ('Dalam', 'OTHER'),
#  ('video', 'OTHER'),
#  ('pendek', 'OTHER'),
#  ('terbitan', 'OTHER'),
# ...

# %%
model.predict(string1)
# Out:
# [('memperkenalkan', 'OTHER'),
#  ('Husein', 'person'),
#  (',', 'OTHER'),
#  ('dia', 'OTHER'),
#  ('sangat', 'OTHER'),
#  ('comel', 'OTHER'),
#  (',', 'OTHER'),
#  ('berumur', 'OTHER'),
#  ('25', 'OTHER'),
#  ('tahun', 'OTHER'),
#  (',', 'OTHER'),
#  ('bangsa', 'OTHER'),
#  ('melayu', 'person'),
#  (',', 'OTHER'),
#  ('agama', 'OTHER'),
#  ('islam', 'person'),
#  (',', 'OTHER'),
#  ('tinggal', 'OTHER'),
#  ('di', 'OTHER'),
#  ('cyberjaya', 'location'),
#  ('malaysia', 'location'),
#  (',', 'OTHER'),
#  ('bercakap', 'OTHER'),
#  ('bahasa', 'OTHER'),
#  ('melayu', 'location'),
#  (',', 'OTHER'),
#  ('semua', 'OTHER'),
#  ('membaca', 'OTHER'),
#  ('buku', 'OTHER'),
#  ('undang-undang', 'OTHER'),
#  ('kewangan', 'OTHER'),
#  (',', 'OTHER'),
#  ('dengar', 'OTHER'),
#  ('laju', 'OTHER'),
#  ('Siti', 'person'),
#  ('Nurhaliza', 'person'),
#  ('-', 'OTHER'),
#  ('Seluruh', 'OTHER'),
#  ('Cinta', 'OTHER'),
#  ('sambil', 'OTHER'),
#  ('makan', 'OTHER'),
#  ('ayam', 'OTHER'),
# ...

# %% [markdown]
# # **Question:**
#
# Select only one sentence:
#
# Sentence 1)
#
# "Mental fizikal aku ni dah penat sebenarnya 😢 aku tak tahu sampai bila mampu bertahan (tapi selalu pujuk diri katakan yang diri aku ni kuat), dengan assignment yang kelaut, makan tak selera, asyik moody je, banyak benda aku takleh gooo Aku rindu diri aku yang dulu, sentiasa happy go lucky dan bersemangat dalam semua perkara tanpa rasa sunyi, sedih dan murung tiap hari."
#
# Sentence 2)
#
# I have been on Celexa 40mg for over 18 YEARS. It's NOT working and I really need to change but I'm so scared that I'll get even WORSE!! My Dr. has given me a month of Prozac but I never took it because of fear. This month he gave me a new drug Trintellix but I haven't started it yet either. I'm SO ON THE EDGE that I'm too scared to try something new because if it doesn't work (or God forbid, makes me WORSE.....) then I just know I for sure won't make it. What should I do? Has anyone else been too scared to try other new or different meds??

# %% [markdown]
# ## Q1: Discuss the preprocessing steps that are needed to clean up the text before it can be sent to the information extractor.

# %% [markdown]
# Answer:
# 1. Expand Contractions
# 2. Convert to lowercase
# 3. Remove punctuations
# 4. Remove digits and whitespace
# 5. Tokenisation
# 6. Remove stopwords

# %%
sentence1 = "Mental fizikal aku ni dah penat sebenarnya 😢 aku tak tahu sampai bila mampu bertahan (tapi selalu pujuk diri katakan yang diri aku ni kuat), dengan assignment yang kelaut, makan tak selera, asyik moody je, banyak benda aku takleh gooo Aku rindu diri aku yang dulu, sentiasa happy go lucky dan bersemangat dalam semua perkara tanpa rasa sunyi, sedih dan murung tiap hari."
#or
sentence2 = "I have been on Celexa 40mg for over 18 YEARS. It's NOT working and I really need to change but I'm so scared that I'll get even WORSE!! My Dr. has given me a month of Prozac but I never took it because of fear. This month he gave me a new drug Trintellix but I haven't started it yet either. I'm SO ON THE EDGE that I'm too scared to try something new because if it doesn't work (or God forbid, makes me WORSE.....) then I just know I for sure won't make it. What should I do? Has anyone else been too scared to try other new or different meds??"

# %% [markdown]
# ## Q2: Clean your input data with the preprocessing steps as discussed in Q1.

# %% [markdown]
# We choose sentence2 as our input data.

# %%
# To expand word contractions
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# To expand word contractions
import contractions

# Create an empty list
expanded = []   
for word in sentence2.split():
  expanded.append(contractions.fix(word))  
   
s2 = ' '.join(expanded)
print(s2)
# Out:
# I have been on Celexa 40mg for over 18 YEARS. It is NOT working and I really need to change but I am so scared that I will get even WORSE!! My Dr. has given me a month of Prozac but I never took it because of fear. This month he gave me a new drug Trintellix but I have not started it yet either. I am SO ON THE EDGE that I am too scared to try something new because if it does not work (or God forbid, makes me WORSE.....) then I just know I for sure will not make it. What should I do? Has anyone else been too scared to try other new or different meds??

# %%
import string
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Convert to lowercase
s2 = s2.lower()

# Remove punctuation
s2 = s2.translate(str.maketrans('', '', string.punctuation))

# Remove digits
s2 = re.sub(r'\d+', '', s2) # replace digits with ''

# Remove whitespace
s2 = s2.strip()

# Remove stopwords
stop_words = set(stopwords.words('english'))
print(s2)
# Out:
# i have been on celexa mg for over  years it is not working and i really need to change but i am so scared that i will get even worse my dr has given me a month of prozac but i never took it because of fear this month he gave me a new drug trintellix but i have not started it yet either i am so on the edge that i am too scared to try something new because if it does not work or god forbid makes me worse then i just know i for sure will not make it what should i do has anyone else been too scared to try other new or different meds

# %% [markdown]
# # Using NLTK

# %% [markdown]
# ## Q3: Write a code to identify part of speech tagging for each of the word.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('words')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize each sentence into words: token_sentence
token_sentence = word_tokenize(sentence2) 
print(token_sentence)

# Tag each tokenized sentence into parts of speech: pos_sentence
pos_sentence = nltk.pos_tag(token_sentence) 
print(pos_sentence)

# Observe output style
for word_post in pos_sentence:
  print (word_post)
# Out:
# ['I', 'have', 'been', 'on', 'Celexa', '40mg', 'for', 'over', '18', 'YEARS', '.', 'It', "'s", 'NOT', 'working', 'and', 'I', 'really', 'need', 'to', 'change', 'but', 'I', "'m", 'so', 'scared', 'that', 'I', "'ll", 'get', 'even', 'WORSE', '!', '!', 'My', 'Dr.', 'has', 'given', 'me', 'a', 'month', 'of', 'Prozac', 'but', 'I', 'never', 'took', 'it', 'because', 'of', 'fear', '.', 'This', 'month', 'he', 'gave', 'me', 'a', 'new', 'drug', 'Trintellix', 'but', 'I', 'have', "n't", 'started', 'it', 'yet', 'either', '.', 'I', "'m", 'SO', 'ON', 'THE', 'EDGE', 'that', 'I', "'m", 'too', 'scared', 'to', 'try', 'something', 'new', 'because', 'if', 'it', 'does', "n't", 'work', '(', 'or', 'God', 'forbid', ',', 'makes', 'me', 'WORSE', '...', '..', ')', 'then', 'I', 'just', 'know', 'I', 'for', 'sure', 'wo', "n't", 'make', 'it', '.', 'What', 'should', 'I', 'do', '?', 'Has', 'anyone', 'else', 'been', 'too', 'scared', 'to', 'try', 'other', 'new', 'or', 'different', 'meds', '?', '?']
# ...

# %%
# Exract noun from the POST
for word_post in pos_sentence:
  if(word_post[1]=="NN"):
    print(word_post[0])
  if(word_post[1]=="NNP"):
    print(word_post[0])
  if(word_post[1]=="NNS"):
    print(word_post[0])
# Out:
# Celexa
# YEARS
# NOT
# Dr.
# month
# Prozac
# fear
# month
# drug
# Trintellix
# THE
# EDGE
# something
# God
# forbid
# ..
# Has
# anyone
# meds

# %% [markdown]
# ## Q4: Write a code to identify NER in your input sentence.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize
sentences = nltk.sent_tokenize(sentence2)

# Tokenize each sentence into words: token_sentences
token_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences]

# Create the named entity chunks: chunked_sentences
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary=True)

# Test for stems of the tree with 'NE' tags
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, "label") and chunk.label() == 'NE':
            print(chunk)
# Out:
# (NE THE/NNP EDGE/NNP)
# (NE Has/NNP)

# %% [markdown]
# ##Q5: Can your code identify any Named Entity inside your input text?

# %%
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary=False)

# %%
import matplotlib.pyplot as plt
from collections import defaultdict

# Create the defaultdict: ner_categories
ner_categories = defaultdict(int)

# Create the nested for loop
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, 'label'):
            ner_categories[chunk.label()] += 1
            
# Create a list from the dictionary keys for the cart labels: labels
labels = list(ner_categories.keys())

# Create a list of the values: values
values = [ner_categories.get(l) for l in labels]

# Create the pie chart
fig = plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140);

# %% [markdown]
# # Using Malaya Toolkit

# %% [markdown]
# ## Q3: Write a code to identify part of speech tagging for each of the word.

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from googletrans import Translator
translator = Translator()

# %%
translated2 = translator.translate(sentence2 ,src='en', dest='ms')
print(translated2)
translated2 = translated2.text
print(translated2)
# Out:
# Translated(src=en, dest=ms, text=Saya telah menggunakan Celexa 40mg selama lebih 18 TAHUN. Ia TIDAK berkesan dan saya benar-benar perlu berubah tetapi saya sangat takut bahawa saya akan menjadi lebih TERUK!! Dr saya telah memberi saya Prozac sebulan tetapi saya tidak pernah mengambilnya kerana takut. Bulan ini dia memberi saya ubat baru Trintellix tetapi saya juga belum memulakannya. I'M SO ON THE EDGE sehinggakan saya terlalu takut untuk mencuba sesuatu yang baru kerana jika ia tidak berkesan (atau ditakdirkan Allah, menjadikan saya TERUK.....) maka saya hanya tahu saya pasti tidak akan berjaya. . Apa patut saya buat? Adakah sesiapa yang terlalu takut untuk mencuba ubat baru atau berbeza yang lain??, pronunciation=[[]], extra_data="{'translat...")
# ...

# %%
# !pip install malaya
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import malaya

# %%
model = malaya.pos.transformer(model = 'albert')

# %%
model.predict(translated2)
# Out:
# [('Saya', 'PRON'),
#  ('telah', 'ADV'),
#  ('menggunakan', 'VERB'),
#  ('Celexa', 'PROPN'),
#  ('40mg', 'NUM'),
#  ('selama', 'ADP'),
#  ('lebih', 'ADV'),
#  ('18', 'NUM'),
#  ('TAHUN', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('Ia', 'PRON'),
#  ('TIDAK', 'PART'),
#  ('berkesan', 'VERB'),
#  ('dan', 'CCONJ'),
#  ('saya', 'PRON'),
#  ('benar-benar', 'ADV'),
#  ('perlu', 'ADV'),
#  ('berubah', 'VERB'),
#  ('tetapi', 'SCONJ'),
#  ('saya', 'PRON'),
#  ('sangat', 'ADV'),
#  ('takut', 'VERB'),
#  ('bahawa', 'SCONJ'),
#  ('saya', 'PRON'),
#  ('akan', 'ADV'),
#  ('menjadi', 'VERB'),
#  ('lebih', 'ADV'),
#  ('TERUK', 'PROPN'),
#  ('!', 'PUNCT'),
#  ('!', 'PUNCT'),
#  ('Dr', 'ADV'),
#  ('saya', 'PRON'),
#  ('telah', 'ADV'),
#  ('memberi', 'VERB'),
#  ('saya', 'PRON'),
#  ('Prozac', 'PROPN'),
#  ('sebulan', 'NOUN'),
#  ('tetapi', 'SCONJ'),
#  ('saya', 'PRON'),
#  ('tidak', 'PART'),
#  ('pernah', 'ADV'),
#  ('mengambilnya', 'VERB'),
#  ('kerana', 'SCONJ'),
#  ('takut', 'VERB'),
#  ('.', 'PUNCT'),
# ...

# %% [markdown]
# ## Q4: Write a code to identify NER in your input sentence.

# %%
model = malaya.entity.transformer(model = 'bert')

# %%
ner_malay = model.predict(translated2)
ner_malay
# Out:
# [('Saya', 'OTHER'),
#  ('telah', 'OTHER'),
#  ('menggunakan', 'OTHER'),
#  ('Celexa', 'OTHER'),
#  ('40mg', 'OTHER'),
#  ('selama', 'OTHER'),
#  ('lebih', 'OTHER'),
#  ('18', 'time'),
#  ('TAHUN', 'time'),
#  ('.', 'OTHER'),
#  ('Ia', 'OTHER'),
#  ('TIDAK', 'OTHER'),
#  ('berkesan', 'OTHER'),
#  ('dan', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('benar-benar', 'OTHER'),
#  ('perlu', 'OTHER'),
#  ('berubah', 'OTHER'),
#  ('tetapi', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('sangat', 'OTHER'),
#  ('takut', 'OTHER'),
#  ('bahawa', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('akan', 'OTHER'),
#  ('menjadi', 'OTHER'),
#  ('lebih', 'OTHER'),
#  ('TERUK', 'OTHER'),
#  ('!', 'OTHER'),
#  ('!', 'OTHER'),
#  ('Dr', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('telah', 'OTHER'),
#  ('memberi', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('Prozac', 'organization'),
#  ('sebulan', 'time'),
#  ('tetapi', 'OTHER'),
#  ('saya', 'OTHER'),
#  ('tidak', 'OTHER'),
#  ('pernah', 'OTHER'),
#  ('mengambilnya', 'OTHER'),
#  ('kerana', 'OTHER'),
# ...

# %% [markdown]
# ##Q5: Can your code identify any Named Entity inside your input text?

# %%
from collections import defaultdict

# Create the defaultdict: ner_categories
ner_categories = defaultdict(int)
ner_categories_malay = defaultdict(list)

# Store all the ner label except OTHER
for token in ner_malay:
  if token[1] != 'OTHER':
    ner_categories[token[1]] += 1
    ner_categories_malay[token[1]].append(token[0])
            
# Create a list from the dictionary keys for the cart labels: labels
labels = list(ner_categories.keys())

# Create a list of the values: values
values = [ner_categories.get(l) for l in labels]

# Create the pie chart
fig = plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140);

# %% [markdown]
# # Group Name: 3 Girls 1 Boy
#
# Student List:
# 1. KOH KAI XUAN (A179338)
#
# 2. CHONG WEI YI (A180497)
#
# 3. JACQUELINE HII SING HEE (A179361)
#
# 4. JACKSON KEK HAI WEI (A170284)
