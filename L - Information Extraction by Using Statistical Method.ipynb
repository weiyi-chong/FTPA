# %% [markdown]
# ## NGRAM

# %% [markdown]
# 1. Import NLTK

# %%
import nltk
from nltk.util import pad_sequence
from nltk.util import bigrams
from nltk.util import ngrams
from nltk.util import everygrams

# %% [markdown]
# 2. Pre-processing : Clean the data (if from social media)

# %%
# Analyse the input sentence
sentence = "The National University of Malaysia (Malay: Universiti Kebangsaan Malaysia, abbreviated as UKM), is a public university located in Bandar Baru Bangi, Selangor which is at south of Kuala Lumpur. Its teaching hospital, Universiti Kebangsaan Malaysia Medical Centre (UKMMC) is located in Cheras and also has a branch campus in Kuala Lumpur.’"

# %%
n = 2
bigrams = ngrams(sentence.split(), n)

for grams in bigrams:
  print(grams)
# Out:
# ('The', 'National')
# ('National', 'University')
# ('University', 'of')
# ('of', 'Malaysia')
# ('Malaysia', '(Malay:')
# ('(Malay:', 'Universiti')
# ('Universiti', 'Kebangsaan')
# ('Kebangsaan', 'Malaysia,')
# ('Malaysia,', 'abbreviated')
# ('abbreviated', 'as')
# ('as', 'UKM),')
# ('UKM),', 'is')
# ('is', 'a')
# ('a', 'public')
# ('public', 'university')
# ('university', 'located')
# ('located', 'in')
# ('in', 'Bandar')
# ('Bandar', 'Baru')
# ('Baru', 'Bangi,')
# ('Bangi,', 'Selangor')
# ('Selangor', 'which')
# ('which', 'is')
# ('is', 'at')
# ('at', 'south')
# ('south', 'of')
# ('of', 'Kuala')
# ('Kuala', 'Lumpur.')
# ('Lumpur.', 'Its')
# ('Its', 'teaching')
# ('teaching', 'hospital,')
# ('hospital,', 'Universiti')
# ('Universiti', 'Kebangsaan')
# ('Kebangsaan', 'Malaysia')
# ('Malaysia', 'Medical')
# ('Medical', 'Centre')
# ('Centre', '(UKMMC)')
# ('(UKMMC)', 'is')
# ('is', 'located')
# ('located', 'in')
# ('in', 'Cheras')
# ('Cheras', 'and')
# ('and', 'also')
# ('also', 'has')
# ...

# %%
n = 3
trigrams = ngrams(sentence.split(), n)

for grams in trigrams:
  print(grams)
# Out:
# ('The', 'National', 'University')
# ('National', 'University', 'of')
# ('University', 'of', 'Malaysia')
# ('of', 'Malaysia', '(Malay:')
# ('Malaysia', '(Malay:', 'Universiti')
# ('(Malay:', 'Universiti', 'Kebangsaan')
# ('Universiti', 'Kebangsaan', 'Malaysia,')
# ('Kebangsaan', 'Malaysia,', 'abbreviated')
# ('Malaysia,', 'abbreviated', 'as')
# ('abbreviated', 'as', 'UKM),')
# ('as', 'UKM),', 'is')
# ('UKM),', 'is', 'a')
# ('is', 'a', 'public')
# ('a', 'public', 'university')
# ('public', 'university', 'located')
# ('university', 'located', 'in')
# ('located', 'in', 'Bandar')
# ('in', 'Bandar', 'Baru')
# ('Bandar', 'Baru', 'Bangi,')
# ('Baru', 'Bangi,', 'Selangor')
# ('Bangi,', 'Selangor', 'which')
# ('Selangor', 'which', 'is')
# ('which', 'is', 'at')
# ('is', 'at', 'south')
# ('at', 'south', 'of')
# ('south', 'of', 'Kuala')
# ('of', 'Kuala', 'Lumpur.')
# ('Kuala', 'Lumpur.', 'Its')
# ('Lumpur.', 'Its', 'teaching')
# ('Its', 'teaching', 'hospital,')
# ...

# %% [markdown]
# ### Text Classification Application:
# I am going to KIV this part. We will look at this example when we have studied text classification.
#
# Improving text classification by using NGRAM
# Source: https://towardsdatascience.com/leveraging-n-grams-to-extract-context-from-text-bdc576b47049

# %% [markdown]
# ## YAKE - Yet Another Keyword Extraction
#
# source: http://yake.inesctec.pt/

# %%
# !pip install yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 132 kB 14.5 MB/s
# ...
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74015 sha256=e7b3e4909c8d2e45b7c514352f6206eb8b75161b4a7840f7e7ddc0f611e8fe30
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# ...

# %%
import yake

text = "Sources tell us that Google is acquiring Kaggle, a platform that hosts data science and machine learning "\
"competitions. Details about the transaction remain somewhat vague, but given that Google is hosting its Cloud "\
"Next conference in San Francisco this week, the official announcement could come as early as tomorrow. "\
"Reached by phone, Kaggle co-founder CEO Anthony Goldbloom declined to deny that the acquisition is happening. "\
"Google itself declined 'to comment on rumors'. Kaggle, which has about half a million data scientists on its platform, "\
"was founded by Goldbloom  and Ben Hamner in 2010. "\

# %%
kw_extractor = yake.KeywordExtractor()
keywords = kw_extractor.extract_keywords(text)

for kw in keywords:
	print(kw)
 
# the lower the score, the better the result
# Out:
# ('machine learning competitions', 0.007544900412276495)
# ('hosts data science', 0.030770508681711477)
# ('learning competitions', 0.03367025053090017)
# ('science and machine', 0.04591873674093405)
# ('machine learning', 0.04591873674093405)
# ('CEO Anthony Goldbloom', 0.050729770926386114)
# ('San Francisco', 0.062366381421386355)
# ('Google', 0.07181316605031703)
# ('Google is acquiring', 0.08045073622117399)
# ('acquiring Kaggle', 0.08742343814254878)
# ('co-founder CEO Anthony', 0.08894398946597894)
# ('Francisco this week', 0.10435066688181596)
# ('Anthony Goldbloom declined', 0.10816714834691311)
# ('CEO Anthony', 0.11235650406785436)
# ('Kaggle co-founder CEO', 0.11342743747259343)
# ('Kaggle', 0.12789746707373223)
# ('hosts data', 0.12860653599328545)
# ('data science', 0.12860653599328545)
# ('hosting its Cloud', 0.13139804593982027)
# ('Cloud Next conference', 0.13139804593982027)

# %%
text_malay ="Kementerian Kesihatan Malaysia (KKM) menyarankan dos penggalak pertama kepada semua jemaah yang bakal menunaikan ibadah mereka manakala dos penggalak kedua bagi golongan yang berisiko. Oleh itu, dikongsikan saranan pengambilan dos penggalak kepada bakal Jemaah haji mengikut kumpulan umur dan faktor risiko. Jemaah haji yang terlibat boleh mendapatkan dos penggalak dengan hadir secara terus tanpa janji temu (walk-in) di PPV yang masih beroperasi dengan membawa dokumen sokongan berkaitan (seperti bukti surat tawaran menunaikan haji)"

# %%
kw_extractor = yake.KeywordExtractor()
keywords = kw_extractor.extract_keywords(text_malay)

for kw in keywords:
	print(kw)
# Out:
# ('Kementerian Kesihatan Malaysia', 0.0008797034329745956)
# ('Kesihatan Malaysia', 0.005613032725849979)
# ('ibadah mereka manakala', 0.00995601850854702)
# ('kedua bagi golongan', 0.00995601850854702)
# ('Kementerian Kesihatan', 0.013030768234670696)
# ('pertama kepada semua', 0.018196673909915015)
# ('penggalak kedua bagi', 0.018491259431399672)
# ('mereka manakala dos', 0.018491259431399676)
# ('golongan yang berisiko', 0.0208625615572248)
# ('menunaikan ibadah mereka', 0.02354485434741842)
# ('menyarankan dos penggalak', 0.02521473081876619)
# ('bagi golongan yang', 0.029142562378879616)
# ('kepada semua jemaah', 0.029872048123250956)
# ('penggalak pertama kepada', 0.03451624890743597)
# ('dos penggalak pertama', 0.035101751601417826)
# ('manakala dos penggalak', 0.035101751601417826)
# ('dos penggalak kedua', 0.035101751601417826)
# ('dos penggalak', 0.03775175405607811)
# ('bakal menunaikan ibadah', 0.04451060025415592)
# ('ibadah mereka', 0.044711933796445225)

# %% [markdown]
# ## RAKE - Rapid Automatic Keyword Extraction.

# %%
# !pip install rake-nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 7.0 MB/s
# ...
#      |████████████████████████████████| 749 kB 51.7 MB/s
# ...
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = "Sources tell us that Google is acquiring Kaggle, a platform that hosts data science and machine learning "\
"competitions. Details about the transaction remain somewhat vague, but given that Google is hosting its Cloud "\
"Next conference in San Francisco this week, the official announcement could come as early as tomorrow. "\
"Reached by phone, Kaggle co-founder CEO Anthony Goldbloom declined to deny that the acquisition is happening. "\
"Google itself declined 'to comment on rumors'. Kaggle, which has about half a million data scientists on its platform, "\
"was founded by Goldbloom  and Ben Hamner in 2010. "\

# %%
from rake_nltk import Rake

# Uses stopwords for english from NLTK, and all puntuation characters by
# default
r = Rake()

# Extraction given the text.
r.extract_keywords_from_text(text)

# To get keyword phrases ranked highest to lowest.
r.get_ranked_phrases()

# To get keyword phrases ranked highest to lowest with scores.
r.get_ranked_phrases_with_scores()

# higher score, better results
# Out:
# [(21.0, 'founder ceo anthony goldbloom declined'),
#  (16.0, 'transaction remain somewhat vague'),
#  (16.0, 'official announcement could come'),
#  (9.0, 'sources tell us'),
#  (9.0, 'million data scientists'),
#  (9.0, 'machine learning competitions'),
#  (9.0, 'hosts data science'),
#  (9.0, 'cloud next conference'),
#  (4.0, 'san francisco'),
#  (4.0, "rumors '."),
#  (4.0, 'ben hamner'),
#  (3.666666666666667, 'kaggle co'),
#  (3.666666666666667, 'acquiring kaggle'),
#  (3.0, 'goldbloom'),
#  (3.0, 'declined'),
#  (1.6666666666666667, 'kaggle'),
#  (1.0, 'week'),
#  (1.0, 'tomorrow'),
#  (1.0, 'reached'),
#  (1.0, 'platform'),
#  (1.0, 'platform'),
#  (1.0, 'phone'),
#  (1.0, 'hosting'),
#  (1.0, 'happening'),
#  (1.0, 'half'),
#  (1.0, 'google'),
#  (1.0, 'google'),
#  (1.0, 'google'),
#  (1.0, 'given'),
#  (1.0, 'founded'),
#  (1.0, 'early'),
#  (1.0, 'details'),
#  (1.0, 'deny'),
#  (1.0, 'comment'),
#  (1.0, 'acquisition'),
#  (1.0, '2010')]

# %% [markdown]
# ## TextRank

# %%
# !pip install summa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 54 kB 3.0 MB/s
# ...
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54412 sha256=87a1e0fa7bd298174b0131c60ea833a0201857362be703e4d2b779d25f40bdd0
#   Stored in directory: /root/.cache/pip/wheels/29/64/ac/7b443477588d365ef37ada30d456bdf5f07dc5be9f6324cb6e
# Successfully built summa
# ...

# %%
from summa import keywords

keyword_list = keywords.keywords(text)
print(keyword_list)
# Out:
# sources tell
# data
# francisco
# san
# tomorrow
